# %% [markdown]
# OBESITY CASE STUDY#

# %%
#%matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
OBCASE=pd.read_csv('USDA.csv')

# %%
type(OBCASE)
# Out:
# pandas.core.frame.DataFrame

# %%
OBCASE.shape
# Out:
# (7058, 16)

# %%
OBCASE.head()
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 2     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 3  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 4   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#    VitaminC  VitaminE  VitaminD
# 0       0.0      2.32       1.5
# ...

# %%
OBCASE.tail()
# Out:
#          ID                 Description  Calories  Protein  TotalFat  \
# 7053  80200               FROG LEGS,RAW      73.0    16.40      0.30
# 7054  83110             MACKEREL,SALTED     305.0    18.50     25.10
# 7055  90240  SCALLOP,(BAY&SEA),CKD,STMD     111.0    20.54      0.84
# 7056  90560                   SNAIL,RAW      90.0    16.10      1.40
# 7057  93600            TURTLE,GREEN,RAW      89.0    19.80      0.50
#
#       Carbohydrate  Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  \
# 7053          0.00    58.0         0.076         50.0    0.0     18.0  1.50
# 7054          0.00  4450.0         7.148         95.0    0.0     66.0  1.40
# 7055          5.41   667.0         0.218         41.0    0.0     10.0  0.58
# 7056          2.00    70.0         0.361         50.0    0.0     10.0  3.50
# 7057          0.00    68.0         0.127         50.0    0.0    118.0  1.40
#
#       Potassium  VitaminC  VitaminE  VitaminD
# 7053      285.0       0.0      1.00       0.2
# ...

# %% [markdown]
# # Statistical Information

# %%
OBCASE.describe()
# Out:
#                  ID     Calories      Protein     TotalFat  Carbohydrate  \
# count   7058.000000  7057.000000  7057.000000  7057.000000   7057.000000
# mean   14259.821196   219.695338    11.710368    10.320614     20.697860
# std     8577.179705   172.198755    10.919356    16.814191     27.630443
# min     1001.000000     0.000000     0.000000     0.000000      0.000000
# 25%     8387.250000    85.000000     2.290000     0.720000      0.000000
# 50%    13293.500000   181.000000     8.200000     4.370000      7.130000
# 75%    18336.750000   331.000000    20.430000    12.700000     28.170000
# max    93600.000000   902.000000    88.320000   100.000000    100.000000
#
#              Sodium  SaturatedFat  Cholesterol        Sugar      Calcium  \
# count   6974.000000   6757.000000  6770.000000  5148.000000  6922.000000
# mean     322.059220      3.452267    41.551994     8.256540    73.530627
# std     1045.416931      6.921267   122.963028    15.361509   222.445338
# ...

# %%
OBCASE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 16 columns):
# ID              7058 non-null int64
# Description     7058 non-null object
# Calories        7057 non-null float64
# Protein         7057 non-null float64
# TotalFat        7057 non-null float64
# Carbohydrate    7057 non-null float64
# Sodium          6974 non-null float64
# SaturatedFat    6757 non-null float64
# Cholesterol     6770 non-null float64
# Sugar           5148 non-null float64
# Calcium         6922 non-null float64
# Iron            6935 non-null float64
# Potassium       6649 non-null float64
# VitaminC        6726 non-null float64
# VitaminE        4338 non-null float64
# VitaminD        4224 non-null float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 882.3+ KB

# %%
OBCASE['High_Sodium'] = OBCASE['Sodium'] > 10000
OBCASE
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 2      1003                               BUTTER OIL,ANHYDROUS     876.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      98.0
# ...

# %%
OBCASE.sort_values('Sodium',ascending=False)
# Out:
#          ID                                        Description  Calories  \
# 264    2047                                         SALT,TABLE       0.0
# 5323  18372                       LEAVENING AGENTS,BAKING SODA       0.0
# 5697  19225                    DESSERTS,RENNIN,TABLETS,UNSWTND      84.0
# 921    6075                  SOUP,BF BROTH OR BOUILLON,PDR,DRY     213.0
# 922    6076                          SOUP,BEEF BROTH,CUBED,DRY     170.0
# 925    6081                         SOUP,CHICK BROTH CUBES,DRY     198.0
# 924    6080                   SOUP,CHICK BROTH OR BOUILLON,DRY     267.0
# 1302   6979                                       ADOBO FRESCO     271.0
# 937    6115                                   GRAVY,AU JUS,DRY     313.0
# 5320  18369  LEAVENING AGENTS,BAKING PDR,DOUBLE-ACTING,NA A...      53.0
# 7024  43497                             JELLYFISH,DRIED,SALTED      36.0
# 923    6077                             SOUP,BF NOODLE,DRY,MIX     324.0
# ...

# %% [markdown]
# # Food Contain Max Sodium Value

# %%
OBCASE.Description[264]
# Out:
# 'SALT,TABLE'

# %% [markdown]
# # foods contain more than 10,000 milligrams of sodium

# %%
OBCASE[OBCASE.High_Sodium==True]
# Out:
#          ID                                        Description  Calories  \
# 264    2047                                         SALT,TABLE       0.0
# 921    6075                  SOUP,BF BROTH OR BOUILLON,PDR,DRY     213.0
# 922    6076                          SOUP,BEEF BROTH,CUBED,DRY     170.0
# 924    6080                   SOUP,CHICK BROTH OR BOUILLON,DRY     267.0
# 925    6081                         SOUP,CHICK BROTH CUBES,DRY     198.0
# 937    6115                                   GRAVY,AU JUS,DRY     313.0
# 1302   6979                                       ADOBO FRESCO     271.0
# 5320  18369  LEAVENING AGENTS,BAKING PDR,DOUBLE-ACTING,NA A...      53.0
# 5323  18372                       LEAVENING AGENTS,BAKING SODA       0.0
# 5697  19225                    DESSERTS,RENNIN,TABLETS,UNSWTND      84.0
#
#       Protein  TotalFat  Carbohydrate   Sodium  SaturatedFat  Cholesterol  \
# 264      0.00      0.00          0.00  38758.0         0.000          0.0
# ...

# %% [markdown]
# # Caviar presence in High_Sodium Data Frame-Ans No

# %%
OBCASE[OBCASE['Description']=='CAVIAR']
# Out:
#          ID Description  Calories  Protein  TotalFat  Carbohydrate  Sodium  \
# 4153  15012      CAVIAR     264.0     24.6      17.9           4.0  1500.0
#
#       SaturatedFat  Cholesterol  Sugar  Calcium   Iron  Potassium  VitaminC  \
# 4153          4.06        588.0    0.0    275.0  11.88      181.0       0.0
#
#       VitaminE  VitaminD  High_Sodium
# 4153      1.89       2.9        False

# %%
OBCASE.High_Sodium[4153]
# Out:
# False

# %% [markdown]
# # How much sodium content is present in 100 grams of "caviar"?-Ans 1500

# %%
OBCASE[OBCASE.Description == 'CAVIAR']['Sodium'].values[0]
# Out:
# 1500.0

# %%
OBCASE['Sodium'].mean()
# Out:
# 322.05921995985085

# %%
OBCASE['TotalFat'].mean()
# Out:
# 10.320613575173555

# %%
OBCASE['Iron'].mean()
# Out:
# 2.828367700072105

# %%
OBCASE['Sodium_Average']=OBCASE['Sodium']>OBCASE['Sodium'].mean()
OBCASE
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 2      1003                               BUTTER OIL,ANHYDROUS     876.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      98.0
# ...

# %%
OBCASE[OBCASE.Sodium_Average==True]
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      98.0
# 12     1013                        CHEESE,COTTAGE,CRMD,W/FRUIT      97.0
# ...

# %% [markdown]
# # Count of foods have higher sodium level than average-Ans-2090

# %%
OBCASE[OBCASE.Sodium_Average==True].count()
# Out:
# ID                2090
# Description       2090
# Calories          2090
# Protein           2090
# TotalFat          2090
# Carbohydrate      2090
# Sodium            2090
# SaturatedFat      2067
# Cholesterol       2033
# Sugar             1716
# Calcium           2026
# Iron              2040
# Potassium         1929
# VitaminC          1974
# VitaminE          1222
# VitaminD          1166
# High_Sodium       2090
# Sodium_Average    2090
# dtype: int64

# %%
OBCASE['Fat_Average']=OBCASE['TotalFat']>OBCASE['TotalFat'].mean()
OBCASE
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 2      1003                               BUTTER OIL,ANHYDROUS     876.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      98.0
# ...

# %%
OBCASE[(OBCASE['Sodium_Average']==True)&(OBCASE['Fat_Average']==True)]
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 17     1018                                        CHEESE,EDAM     357.0
# 18     1019                                        CHEESE,FETA     264.0
# ...

# %% [markdown]
# # Count of foods have higher sodium level & Fat level than average-Ans 712

# %%
OBCASE[(OBCASE['Sodium_Average']==True)&(OBCASE['Fat_Average']==True)].count()
# Out:
# ID                712
# Description       712
# Calories          712
# Protein           712
# TotalFat          712
# Carbohydrate      712
# Sodium            712
# SaturatedFat      704
# Cholesterol       683
# Sugar             575
# Calcium           702
# Iron              704
# Potassium         696
# VitaminC          669
# VitaminE          455
# VitaminD          405
# High_Sodium       712
# Sodium_Average    712
# Fat_Average       712
# dtype: int64

# %%
OBCASE.sort_values('Protein',ascending=False)
# Out:
#          ID                                        Description  Calories  \
# 4660  16423           SOY PROT ISOLATE,K TYPE,CRUDE PROT BASIS     321.0
# 4549  16175  SOY PROT ISOLATE,PROT TECHNOLOGIES INTERNATION...     388.0
# 4550  16176  SOY PROT ISOLATE,PROT TECHNOLOGIES INTERNATION...     380.0
# 5660  19177                           GELATINS,DRY PDR,UNSWTND     335.0
# 6729  35055   SEAL,BEARDED (OOGRUK),MEAT,DRIED (ALASKA NATIVE)     351.0
# 123    1136                    EGG,WHITE,DRIED,PDR,GLUCOSE RED     376.0
# 151    1173                                    EGG,WHITE,DRIED     382.0
# 4511  16122                                SOY PROTEIN ISOLATE     338.0
# 4659  16422                            SOY PROT ISOLATE,K TYPE     326.0
# 6804  35180     STEELHEAD TROUT,DRIED,FLESH (SHOSHONE BANNOCK)     382.0
# 122    1135                 EGG,WHITE,DRIED,FLAKES,GLUCOSE RED     351.0
# 7052  48052                                 VITAL WHEAT GLUTEN     370.0
# ...
